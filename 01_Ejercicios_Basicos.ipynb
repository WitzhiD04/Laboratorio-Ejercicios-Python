# %% [markdown]
# # Laboratorio Databricks - Procesamiento de Datos
# ## Cuaderno 1: Ejercicios Básicos y Manipulación de Cadenas
#
# ---
#
# ### Membrete de Identificación
# - **Nombre Completo:** [Tu Nombre Completo]
# - **Identificación:** [Tu Código/Cédula]
# - **Descripción del Autor:** Estudiante de Ingeniería de Sistemas. Interesado en el procesamiento de datos a gran escala, análisis de datos y computación en la nube mediante Databricks.
# - **Enlace del Repositorio:** [Enlace al Repositorio de GitHub](https://github.com/tu-usuario/tu-repositorio)
#
# ---

# %% [markdown]
# ## Actividad 1: Operaciones con Cadenas
# **Descripción:** Introducción al entorno de ejecución y definición de variables de texto básicas.

# %%
A = "1"
print(A)

B = "2"
print(B)

C = A + B
print(C)

D = "ABCDEFG"
print(D[0:3])

E = 'clocrkr1e1c1t'
print(E[::2])

print("\\")

F = "You are wrong"

F = F.upper()

print(F)

G = "Mary had a little lamb Little lamb, little lamb Mary had a little lamb \
Its fleece was white as snow And everywhere that Mary went Mary went, Mary went \
Everywhere that Mary went The lamb was sure to go"

print(G.find('snow'))

G = G.replace("Mary", "Bob")

print(G)
# Out:
# 1
# 2
# 12
# ABC
# correct
# \
# YOU ARE WRONG
# 95
# Bob had a little lamb Little lamb, little lamb Bob had a little lamb Its fleece was white as snow And everywhere that Bob went Bob went, Bob went Everywhere that Bob went The lamb was sure to go

# %% [markdown]
# ## Conclusiones
